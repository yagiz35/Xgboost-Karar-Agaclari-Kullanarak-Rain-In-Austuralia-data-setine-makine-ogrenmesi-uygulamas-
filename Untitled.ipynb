# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Kütüphaneler eklendi

# %%
data = pd.read_csv("weatherAUS.csv")

# %%
data.describe()
# Out:
#              MinTemp        MaxTemp       Rainfall   Evaporation  \
# count  143975.000000  144199.000000  142199.000000  82670.000000
# mean       12.194034      23.221348       2.360918      5.468232
# std         6.398495       7.119049       8.478060      4.193704
# min        -8.500000      -4.800000       0.000000      0.000000
# 25%         7.600000      17.900000       0.000000      2.600000
# 50%        12.000000      22.600000       0.000000      4.800000
# 75%        16.900000      28.200000       0.800000      7.400000
# max        33.900000      48.100000     371.000000    145.000000
#
#            Sunshine  WindGustSpeed   WindSpeed9am   WindSpeed3pm  \
# count  75625.000000  135197.000000  143693.000000  142398.000000
# mean       7.611178      40.035230      14.043426      18.662657
# std        3.785483      13.607062       8.915375       8.809800
# min        0.000000       6.000000       0.000000       0.000000
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145460 entries, 0 to 145459
# Data columns (total 23 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Date           145460 non-null  object
#  1   Location       145460 non-null  object
#  2   MinTemp        143975 non-null  float64
#  3   MaxTemp        144199 non-null  float64
#  4   Rainfall       142199 non-null  float64
#  5   Evaporation    82670 non-null   float64
#  6   Sunshine       75625 non-null   float64
#  7   WindGustDir    135134 non-null  object
#  8   WindGustSpeed  135197 non-null  float64
#  9   WindDir9am     134894 non-null  object
#  10  WindDir3pm     141232 non-null  object
#  11  WindSpeed9am   143693 non-null  float64
#  12  WindSpeed3pm   142398 non-null  float64
#  13  Humidity9am    142806 non-null  float64
#  14  Humidity3pm    140953 non-null  float64
#  15  Pressure9am    130395 non-null  float64
# ...

# %%
data.dropna(inplace = True)

# %%
data.sort_values(by="Date",inplace = True)

# %% [markdown]
# ## [-6.7] cıkarılamadi

# %%
for column in data.columns[2:-1]:
    sns.scatterplot(data = data , x="Date",y=column,hue="RainTomorrow")
    plt.show()

# %%
data.columns[2:-2]
# Out:
# Index(['MinTemp', 'MaxTemp', 'Rainfall', 'Evaporation', 'Sunshine',
#        'WindGustDir', 'WindGustSpeed', 'WindDir9am', 'WindDir3pm',
#        'WindSpeed9am', 'WindSpeed3pm', 'Humidity9am', 'Humidity3pm',
#        'Pressure9am', 'Pressure3pm', 'Cloud9am', 'Cloud3pm', 'Temp9am',
#        'Temp3pm'],
#       dtype='object')

# %%
data = data.reindex(["Date","Location","MinTemp","MaxTemp","Rainfall","Evaporation",
            "Sunshine","WindGustSpeed","Humidity9am",
            "Humidity3pm","Pressure9am","Pressure3pm",
            "Cloud9am","Cloud3pm","Temp9am","Temp3pm","WindGustDir","WindDir9am","RainToday","RainTomorrow"], axis=1)

# %%
data
# Out:
#               Date      Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 45587   2007-11-01      Canberra      8.0     24.3       0.0          3.4
# 45588   2007-11-02      Canberra     14.0     26.9       3.6          4.4
# 45589   2007-11-03      Canberra     13.7     23.4       3.6          5.8
# 45590   2007-11-04      Canberra     13.3     15.5      39.8          7.2
# 45591   2007-11-05      Canberra      7.6     16.1       2.8          5.6
# ...            ...           ...      ...      ...       ...          ...
# 87199   2017-06-25      Brisbane     11.0     24.2       0.0          2.2
# 120637  2017-06-25  PerthAirport      4.9     16.8       0.0          1.6
# 70392   2017-06-25     Melbourne      8.6     14.3       0.0          2.8
# 123830  2017-06-25         Perth      6.3     17.0       0.0          1.6
# 80997   2017-06-25      Watsonia      7.9     13.0       0.0          2.8
#
#         Sunshine  WindGustSpeed  Humidity9am  Humidity3pm  Pressure9am  \
# ...

# %%
for column in data.columns[2:-5]:
    for ifrainy in data["RainTomorrow"].unique():
        selected_ifrainy = data[data["RainTomorrow"] == ifrainy]
        selected_column = selected_ifrainy[column]
        
        std = selected_column.std()
        avg = selected_column.mean()
        
        three_sigma_plus = avg + (3 * std)
        three_sigma_minus = avg - (3* std)

        outliers = selected_column[(selected_ifrainy[column] > (three_sigma_plus)) | (selected_ifrainy[column] < (three_sigma_minus))].index
        data.drop(index = outliers ,inplace = True)

# %%
data
# Out:
#               Date      Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 45587   2007-11-01      Canberra      8.0     24.3       0.0          3.4
# 45588   2007-11-02      Canberra     14.0     26.9       3.6          4.4
# 45589   2007-11-03      Canberra     13.7     23.4       3.6          5.8
# 45590   2007-11-04      Canberra     13.3     15.5      39.8          7.2
# 45591   2007-11-05      Canberra      7.6     16.1       2.8          5.6
# ...            ...           ...      ...      ...       ...          ...
# 87199   2017-06-25      Brisbane     11.0     24.2       0.0          2.2
# 120637  2017-06-25  PerthAirport      4.9     16.8       0.0          1.6
# 70392   2017-06-25     Melbourne      8.6     14.3       0.0          2.8
# 123830  2017-06-25         Perth      6.3     17.0       0.0          1.6
# 80997   2017-06-25      Watsonia      7.9     13.0       0.0          2.8
#
#         Sunshine  WindGustSpeed  Humidity9am  Humidity3pm  Pressure9am  \
# ...

# %%
for column in data.columns[2:-5]:
    for ifrainy in data["RainTomorrow"].unique():
        selected_ifrainy = data[data["RainTomorrow"] == ifrainy]
        selected_column = selected_ifrainy[column]
        
        q1 = selected_column.quantile(0.25)
        q3 = selected_column.quantile(0.75)
        
        iqr = q3 - q1
        
        minimum = q1 - (1.5 * iqr)
        maximum = q3 + (1.5 * iqr)
        
        max_idxs = data[(data["RainTomorrow"] == ifrainy) & (data[column] > maximum)].index
        min_idxs = data[(data["RainTomorrow"] == ifrainy) & (data[column] < minimum)].index
        
        data.drop(index = max_idxs, inplace = True)
        data.drop(index = min_idxs, inplace = True)

# %%
data.isnull().sum()
# Out:
# Date             0
# Location         0
# MinTemp          0
# MaxTemp          0
# Rainfall         0
# Evaporation      0
# Sunshine         0
# WindGustSpeed    0
# Humidity9am      0
# Humidity3pm      0
# Pressure9am      0
# Pressure3pm      0
# Cloud9am         0
# Cloud3pm         0
# Temp9am          0
# Temp3pm          0
# WindGustDir      0
# WindDir9am       0
# RainToday        0
# RainTomorrow     0
# dtype: int64

# %% [markdown]
# ## Corelation matrisi verilerin birbirleriyle ilişkisini anlamak adına
# plt.figure(figsize =(24,12))
# sns.heatmap(data.corr(), annot = True, cmap="coolwarm")
# plt.show()

# %% [markdown]
# ## Verilerin sayılarını anlamak adına dengesizlik durumunda kod
# for column in data.columns[16:]:
#     plt.figure(figsize =(20,9))
#     sns.countplot(data[column])
#     plt.show()

# %%
from sklearn import preprocessing
le = preprocessing.LabelEncoder()
for column in data.columns[16:]:
    data[column] = le.fit_transform(data[column])

# %%
data.head()
# Out:
#              Date  Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 45587  2007-11-01  Canberra      8.0     24.3       0.0          3.4
# 45592  2007-11-06  Canberra      6.2     16.9       0.0          5.8
# 45593  2007-11-07  Canberra      6.1     18.2       0.2          4.2
# 45594  2007-11-08  Canberra      8.3     17.0       0.0          5.6
# 45595  2007-11-09  Canberra      8.8     19.5       0.0          4.0
#
#        Sunshine  WindGustSpeed  Humidity9am  Humidity3pm  Pressure9am  \
# 45587       6.3           30.0         68.0         29.0       1019.7
# 45592       8.2           44.0         70.0         57.0       1023.8
# 45593       8.4           43.0         63.0         47.0       1024.6
# 45594       4.6           41.0         65.0         57.0       1026.2
# 45595       4.1           48.0         70.0         48.0       1026.1
#
#        Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  WindGustDir  \
# ...

# %%
data["WindGustDir"].nunique()
# Out:
# 16

# %%
oht = preprocessing.
for column in data.columns[16:18]:
    data[column] = oht.fit_transform(data[column])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16884/757439192.py in <module>
#       2 for column in data.columns[16:18]:
#       3     data[column] = data[column].values.reshape(-1,1)
# ----> 4     data[column] = oht.fit_transform(data[column]).toarray()
#
# ~\anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py in fit_transform(self, X, y)
#     449         """
#     450         self._validate_keywords()
# --> 451         return super().fit_transform(X, y)
#     452
#     453     def transform(self, X):
#
# ~\anaconda3\lib\site-packages\sklearn\base.py in fit_transform(self, X, y, **fit_params)
#     697         if y is None:
#     698             # fit method of arity 1 (unsupervised transformation)
# --> 699             return self.fit(X, **fit_params).transform(X)
#     700         else:
# ...

# %%
data.head()
# Out:
#              Date  Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 45587  2007-11-01  Canberra      8.0     24.3       0.0          3.4
# 45592  2007-11-06  Canberra      6.2     16.9       0.0          5.8
# 45593  2007-11-07  Canberra      6.1     18.2       0.2          4.2
# 45594  2007-11-08  Canberra      8.3     17.0       0.0          5.6
# 45595  2007-11-09  Canberra      8.8     19.5       0.0          4.0
#
#        Sunshine  WindGustSpeed  Humidity9am  Humidity3pm  Pressure9am  \
# 45587       6.3           30.0         68.0         29.0       1019.7
# 45592       8.2           44.0         70.0         57.0       1023.8
# 45593       8.4           43.0         63.0         47.0       1024.6
# 45594       4.6           41.0         65.0         57.0       1026.2
# 45595       4.1           48.0         70.0         48.0       1026.1
#
#        Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  WindGustDir  \
# ...

# %%
plt.figure(figsize =(24,12))
sns.heatmap(data.corr(), annot = True, cmap="coolwarm")
plt.show()
